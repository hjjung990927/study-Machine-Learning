# %%
import pandas as pd

cancer_df = pd.read_csv('./datasets/data.csv')
cancer_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
cancer_df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
cancer_df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
radius_df = cancer_df.loc[:, 'radius_mean'].reset_index()
radius_df
# Out:
#      index  radius_mean
# 0        0        17.99
# 1        1        20.57
# 2        2        19.69
# 3        3        11.42
# 4        4        20.29
# ..     ...          ...
# 564    564        21.56
# 565    565        20.13
# 566    566        16.60
# 567    567        20.60
# 568    568         7.76
#
# [569 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()
std_radius = std.fit_transform(radius_df[['radius_mean']])
std_radius
# Out:
# array([[ 1.09706398],
#        [ 1.82982061],
#        [ 1.57988811],
#        [-0.76890929],
#        [ 1.75029663],
#        [-0.47637467],
#        [ 1.17090767],
#        [-0.11851678],
#        [-0.32016686],
#        [-0.47353452],
#        [ 0.53755602],
#        [ 0.46939261],
#        [ 1.43220073],
#        [ 0.4892736 ],
#        [-0.11283649],
#        [ 0.117215  ],
#        [ 0.15697699],
#        [ 0.56879758],
#        [ 1.61396982],
#        [-0.16679919],
#        [-0.29744572],
#        [-1.31308049],
#        [ 0.34442636],
#        [ 1.99738898],
#        [ 0.71648496],
#        [ 0.85565191],
#        [ 0.12857557],
#        [ 1.27315278],
#        [ 0.33306579],
#        [ 0.97777802],
#        [ 1.27883307],
#        [-0.64962332],
#        [ 0.82157021],
#        [ 1.46060215],
#        [ 0.56879758],
#        [ 0.74204624],
#        [ 0.03485089],
#        [-0.31164643],
#        [ 0.24502139],
#        [-0.18384004],
#        [-0.19520061],
# ...

# %%
radius_df.radius_mean = std_radius
radius_df
# Out:
#      index  radius_mean
# 0        0     1.097064
# 1        1     1.829821
# 2        2     1.579888
# 3        3    -0.768909
# 4        4     1.750297
# ..     ...          ...
# 564    564     2.110995
# 565    565     1.704854
# 566    566     0.702284
# 567    567     1.838341
# 568    568    -1.808401
#
# [569 rows x 2 columns]

# %%
condition1 = radius_df.radius_mean >= -1.96
condition2 = radius_df.radius_mean <= 1.96
condition = condition1 & condition2

cancer_df = cancer_df.iloc[radius_df[condition].index]
cancer_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 563    926125         M        20.92         25.09          143.00     1347.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
cancer_enc_df = cancer_df.reset_index()
cancer_enc_df
# Out:
#      index        id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0        0    842302         M        17.99         10.38          122.80
# 1        1    842517         M        20.57         17.77          132.90
# 2        2  84300903         M        19.69         21.25          130.00
# 3        3  84348301         M        11.42         20.38           77.58
# 4        4  84358402         M        20.29         14.34          135.10
# ..     ...       ...       ...          ...           ...             ...
# 541    563    926125         M        20.92         25.09          143.00
# 542    565    926682         M        20.13         28.25          131.20
# 543    566    926954         M        16.60         28.08          108.30
# 544    567    927241         M        20.60         29.33          140.10
# 545    568     92751         B         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# ...

# %%
# from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# radius_encoder = LabelEncoder()
# radius = radius_encoder.fit_transform(cancer_enc_df.radius_mean.tolist())
# cancer_enc_df['radius_mean'] = radius

# %%
cancer_enc_df
# Out:
#      index        id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0        0    842302         M        17.99         10.38          122.80
# 1        1    842517         M        20.57         17.77          132.90
# 2        2  84300903         M        19.69         21.25          130.00
# 3        3  84348301         M        11.42         20.38           77.58
# 4        4  84358402         M        20.29         14.34          135.10
# ..     ...       ...       ...          ...           ...             ...
# 541    563    926125         M        20.92         25.09          143.00
# 542    565    926682         M        20.13         28.25          131.20
# 543    566    926954         M        16.60         28.08          108.30
# 544    567    927241         M        20.60         29.33          140.10
# 545    568     92751         B         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# ...

# %%
# print(radius_encoder.classes_)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

diagnosis_encoder = LabelEncoder()
diagnosis = diagnosis_encoder.fit_transform(cancer_enc_df.diagnosis.tolist())
cancer_enc_df['diagnosis'] = diagnosis

cancer_enc_df
# Out:
#      index        id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0        0    842302          1        17.99         10.38          122.80
# 1        1    842517          1        20.57         17.77          132.90
# 2        2  84300903          1        19.69         21.25          130.00
# 3        3  84348301          1        11.42         20.38           77.58
# 4        4  84358402          1        20.29         14.34          135.10
# ..     ...       ...        ...          ...           ...             ...
# 541    563    926125          1        20.92         25.09          143.00
# 542    565    926682          1        20.13         28.25          131.20
# 543    566    926954          1        16.60         28.08          108.30
# 544    567    927241          1        20.60         29.33          140.10
# 545    568     92751          0         7.76         24.54           47.92
#
# ...

# %%
print(diagnosis_encoder.classes_)
# Out:
# ['B' 'M']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import export_graphviz
import graphviz

# 연산 결과를 파일로 내보내기
dtc = DecisionTreeClassifier()

target = cancer_enc_df['diagnosis']        
features = cancer_enc_df.drop(columns=['diagnosis'])

X_train, X_test, y_train, y_test = \
train_test_split(features, target, test_size=0.2, random_state=124)

dtc.fit(X_train, y_train)

export_graphviz(
    dtc,
    out_file='./images/cancer_dtc01.dot',
    class_names=diagnosis_encoder.classes_,
    feature_names=features.columns,
    impurity=True,
    filled=True
)

# %%
cancer_enc_df['diagnosis'].isna().sum()
# Out:
# np.int64(0)

# %%
cancer_enc_df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
cancer_enc_df = cancer_enc_df.drop(columns=['index', 'id'])

# %%
cancer_enc_df['diagnosis'].unique()
# Out:
# array([1, 0])

# %%
with open('./images/cancer_dtc01.dot') as f:
    cancer_dtc01 = f.read()

cancer_dtc01_graph = graphviz.Source(cancer_dtc01)
# 이미지 파일로 변환해서 내보내기
cancer_dtc01_graph.render(filename='cancer_dtc01', directory='./images', format='png')
# Out:
# 'images\\cancer_dtc01.png'

# %%
dtc.feature_importances_
# Out:
# array([0.01782743, 0.        , 0.        , 0.01166619, 0.        ,
#        0.00826638, 0.        , 0.        , 0.        , 0.02978998,
#        0.        , 0.        , 0.00422713, 0.        , 0.        ,
#        0.01598749, 0.        , 0.01445172, 0.00516649, 0.        ,
#        0.        , 0.01997855, 0.        , 0.02609453, 0.        ,
#        0.13648769, 0.        , 0.        , 0.        , 0.71005642,
#        0.        , 0.        , 0.        ])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(features['radius_mean'], target, c=target, cmap='bwr')
plt.xlabel('radius_mean')
plt.ylabel('diagnosis (0=B, 1=M)')
plt.show()

# %%
import numpy as np

# Classifier의 Decision Boundary를 시각화 하는 함수
def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start , xlim_end = ax.get_xlim()
    ylim_start , ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 . 
    model.fit(X.values, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행. 
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행. 
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow',
                           zorder=1)

# %%
visualize_boundary(dtc, features[['radius_mean', 'texture_mean']], target)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, dtc.predict(X_test[['radius_mean', 'texture_mean']].values))
# Out:
# 1.0
